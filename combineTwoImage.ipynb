# %% [markdown]
# ## Lucifer Dual Face
# #### In task we have two images and we just need to combined it or contatinate it according to our look and feel then finally we have to display it.

# %%
import cv2
import matplotlib.pyplot as plt

# %%
mainPic = cv2.imread('./images/lucifer_duel.jpg')

# %%
First=mainPic[0:600,50:550]
plt.imshow(First)

# %%
FirstPic = mainPic[0:600,425:600]
#cv2.imshow('fram1',FirstPic)
#cv2.waitKey()
#cv2.destroyAllWindows()
plt.imshow(FirstPic)

# %%
Second = mainPic[0:600,600:1200]
plt.imshow(Second)

# %%
SecPic =mainPic[0:600,600:1050]
#cv2.imshow('fram2',SecPic)
#cv2.waitKey()
#cv2.destroyAllWindows()
plt.imshow(SecPic)

# %%
combined = cv2.hconcat([SecPic, FirstPic])
cv2.imshow('MainOutPut',combined)
cv2.waitKey()
cv2.destroyAllWindows()
plt.imshow(combined)
